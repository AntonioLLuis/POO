# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonioLLuis/POO/blob/main/Orienta%C3%A7%C3%A3o_a_Objetos%20Triangulo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Orientação a Objetos

# %%
class Triangulo:
  def __init__(self, lado1, lado2, lado3, base, altura):
    self.lado1 = lado1
    self.lado2 = lado2
    self.lado3 = lado3
    self.base = base
    self.altura = altura

  def area(self):
    return (self.base * self.altura) / 2

  def tipo(self):
    if self.lado1 > self.lado2 + self.lado3:
      return 'não é um triângulo'
    elif self.lado1 == self.lado2 or self.lado1 == self.lado3 or self.lado1 == self.lado2:
      return 'triângulo isósceles'
    else:
      return 'outro tipo de triângulo'

# %%
t1 = Triangulo(5, 5, 3, 4, 3)

# %%
print(t1.lado1, t1.lado2, t1.lado3, t1.base, t1.altura)
# Out:
# 5 1 3 4 3

# %%
t1.area()
# Out:
# 6.0

# %%
t1.tipo()
# Out:
# 'triângulo isósceles'

# %%
t2 = Triangulo(8, 8, 8, 16, 9)
print(t2.lado1, t2.lado2, t2.lado3, t2.base, t2.altura)
# Out:
# 8 8 8 16 9

# %%
t2.area()
# Out:
# 72.0

# %%
t2.tipo()
# Out:
# 'triângulo isósceles'
